# %%
import jmd95
import numpy as np
import netCDF4
from matplotlib import pyplot as plt
from matplotlib.colors import SymLogNorm
# %matplotlib inline
plt.rcParams['image.origin'] = 'bottom'
plt.rcParams['figure.figsize'] = (18,12)

# %%
p = 0
#FILE = netCDF4.Dataset('/glade/scratch/enewsom/HR_ANALYSIS/DATA/LRfiles/LRC01.pop.h1.0147-0167.nc')
FILE = netCDF4.Dataset('/glade/scratch/enewsom/HR_ANALYSIS/DATA/HRfiles/HRC06.br.pop.h1.0147-0167.nc')

S = FILE.variables['SALT'][:,0,:,:]
T = FILE.variables['TEMP'][:,0,:,:]

#out = jmd95.eos.state_surface(T,S)
out = jmd95.eos.state(p,T,S)
jmd95dens0 = out[0]
alpha = -out[1]/jmd95dens0
beta = out[2]/jmd95dens0

p = 2000

#out = jmd95.eos.state_surface(T,S)
out = jmd95.eos.state(p,T,S)
jmd95dens2000 = out[0]
alpha = -out[1]/jmd95dens2000
beta = out[2]/jmd95dens2000

#print 'Potential Density '
#print jmd95dens0
   
#print 'Alpha'
#print alpha
    
#print 'Beta'
#print beta

# %%
fig = plt.figure(figsize=(8,5))
plt.contourf(jmd95dens0-1000,100)#,vmin=8, vmax=30 )
plt.colorbar()
plt.title('LoRes surface potential density relative to 0 meters')

fig = plt.figure(figsize=(8,5))
plt.contourf(jmd95dens2000-1000,100)#,vmin=8, vmax=30 )
plt.colorbar()
plt.title('LoRes surface potential density relative to 2000 meters')

# %%
p = 20000

#out = jmd95.eos.state_surface(T,S)
out = jmd95.eos.state(p,T,S)
jmd95dens20000 = out[0]

# %%
fig = plt.figure(figsize=(8,5))
plt.contourf(jmd95dens20000-1000,100)#,vmin=8, vmax=30 )
plt.colorbar()
plt.title('LoRes surface potential density relative to 20000 meters')

# %%
import scipy.io

# %%
#pdu = scipy.io.loadmat('/glade/scratch/enewsom/HR_ANALYSIS/NEW_ISO_MOC_OUTPUT/GOOD_iso_MOC_files/pdu_surf_LR')
pdu = scipy.io.loadmat('/glade/scratch/enewsom/HR_ANALYSIS/NEW_ISO_MOC_OUTPUT/GOOD_iso_MOC_files/pdu_surf')

# %%
whos
# Out:
# Variable         Type           Data/Info
# -----------------------------------------
# FILE             Dataset        <type 'netCDF4.Dataset'>\<...>lat,nlon)\n    groups: \n
# S                MaskedArray    [[[inf inf inf ..., inf i<...>f inf ..., inf inf inf]]]
# SymLogNorm       type           <class 'matplotlib.colors.SymLogNorm'>
# T                MaskedArray    [[[-- -- -- ..., -- -- --<...>-- -- -- ..., -- -- --]]]
# alpha            ndarray        2400x3600: 8640000 elems, type `float64`, 69120000 bytes (65 Mb)
# beta             ndarray        2400x3600: 8640000 elems, type `float64`, 69120000 bytes (65 Mb)
# fig              Figure         Figure(640x400)
# jmd95            module         <module 'jmd95' from '/gl<...>pop_water_mass/jmd95.so'>
# jmd95dens0       ndarray        2400x3600: 8640000 elems, type `float64`, 69120000 bytes (65 Mb)
# jmd95dens2000    ndarray        2400x3600: 8640000 elems, type `float64`, 69120000 bytes (65 Mb)
# ...

# %%
pdu.keys()
# Out:
# ['pdu_surf', '__version__', '__header__', '__globals__']

# %%
#PDU = pdu['pdu_surf_LR']
PDU = pdu['pdu_surf']
PDU_r = jmd95dens2000-1000

# %%
plt.contourf(PDU.T,100)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2b3f852cf9e0>

# %%
#PDU_r = PDU_r[0:188,:]
PDU_r = PDU_r[0:1202,:]

plt.contourf(PDU_r,100)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2b3fd88d8878>

# %%
fig = plt.figure(figsize=(8,5))

plt.contourf(PDU.T-PDU_r,100)#,vmin = -.2 , vmax = .2)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2b3fe2c06758>

# %%
C = plt.contourf(PDU.T[0:400,1:700]-PDU_r[0:400,1:700],600,cmap = 'jet',vmin = -.2 , vmax = .2)
plt.clim(-.2,.2)
plt.colorbar(C)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2b3ffe1dde60>

# %%
whos
