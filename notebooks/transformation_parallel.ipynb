# %%
from IPython.parallel import Client

c = Client()
dview = c.direct_view()
lview = c.load_balanced_view()

with dview.sync_imports():
    import numpy
    from watermasstools import pop_model, transformation
# Out:
# importing numpy on engine(s)
# importing pop_model,transformation from watermasstools on engine(s)

# %%
ddir = '/glade/p/ncgd0001/hybrid_v5_rel04_BC5_ne120_t12_pop62/ocn-hist'
fprefix = 'hybrid_v5_rel04_BC5_ne120_t12_pop62.pop.h.nday1'
fnames = []
for year in xrange(47,86):
    for month in xrange(1,13):
        fnames.append(
         '%s/%s.%04d-%02d-01.nc' % (ddir, fprefix, year, month)
        )

# %%
# load a test file
p = pop_model.POPFile(fnames[0])

# define basins
natl = transformation.WaterMassRegion(
                    basin_names=['Atlantic Ocean', 'GIN Seas', 'Labrador Sea'], latmin=15)
natl.initialize_mask(p)
natl.set_rholevs(numpy.load('../data/rholevs_natl.npy'))
region_dict = {'natl': natl}

# %%
# push to engines
dview.push({'natl': natl})
dview.execute('region_dict = {"natl": natl}')
# Out:
# <AsyncResult: execute>

# %%
def calc_transformation_rates(pop_fname):
    if isinstance(pop_fname, list):
        fname = pop_fname[0]
    else:
        fname = pop_fname
    
    print fname
    p = pop_model.POPFile(fname)
    p.initialize_gradient_operator()
    Nt = len(p.nc.variables['time'])
    
    result = dict()
    for rname in region_dict:
        result[rname] = 0.
    
    for n in range(Nt):
        print n
        F_temp, F_salt = p.dens_flux[n]
        
        H_ml = p.nc.variables['HMXL_2'][0]/100.
        rho0 = p.rho[n]
        bt = numpy.ma.masked_invalid(
            p.biharmonic_tendency(p.nc.variables['SST'][0]))
        bs = numpy.ma.masked_invalid(
            p.biharmonic_tendency(p.nc.variables['SSS'][0]))

        D_salt = numpy.ma.masked_greater(p.beta[n] * rho0 * H_ml * bs, 1e4)
        D_temp = numpy.ma.masked_greater(-p.alpha[n] * rho0 * H_ml * bt, 1e4)
        
        for rname, reg in region_dict.iteritems():
            A = reg.calculate_transformation_rate(rho0,
                              F_temp, F_salt, D_temp, D_salt)
            result[rname] += A

    for rname in region_dict:
        result[rname] /= Nt
        
    return result

# %%
# all the work is here
#res = lview.imap(calc_transformation_rates,fnames[:32]) # works!
res = lview.map(calc_transformation_rates, fnames) # should work the same way

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
res.progress / float(len(res))
# Out:
# 1.0

# %%
#A = []
#for r in res :
A = numpy.array([r['natl'] for r in res])

# %%
A = []
for r in res:
    try:
        A.append(r['natl'])
    except AttributeError:
        pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-2604f9f61d86> in <module>()
#       1 A = []
# ----> 2 for r in res:
#       3     try:
#       4         A.append(r['natl'])
#       5     except AttributeError:
#
# /glade/apps/opt/ipython/2.1.0/lib/python2.7/site-packages/IPython/parallel/client/asyncresult.pyc in __iter__(self)
#     592     def __iter__(self):
#     593         it = self._ordered_iter if self.ordered else self._unordered_iter
# --> 594         for r in it():
#     595             yield r
#     596
#
# /glade/apps/opt/ipython/2.1.0/lib/python2.7/site-packages/IPython/parallel/client/asyncresult.pyc in _ordered_iter(self)
#     604             for msg_id in self.msg_ids:
#     605                 ar = AsyncResult(self._client, msg_id, self._fname)
# --> 606                 rlist = ar.get()
#     607                 try:
#     608                     for r in rlist:
#
# /glade/apps/opt/ipython/2.1.0/lib/python2.7/site-packages/IPython/parallel/client/asyncresult.pyc in get(self, timeout)
#     110         """
#     111         if not self.ready():
# --> 112             self.wait(timeout)
#     113
#     114         if self._ready:
#
# /glade/apps/opt/ipython/2.1.0/lib/python2.7/site-packages/IPython/parallel/client/asyncresult.pyc in wait(self, timeout)
#     141             self._wait_for_outputs(timeout)
#     142             return
# --> 143         self._ready = self._client.wait(self.msg_ids, timeout)
#     144         if self._ready:
#     145             try:
#
# /glade/apps/opt/ipython/2.1.0/lib/python2.7/site-packages/IPython/parallel/client/client.pyc in wait(self, jobs, timeout)
#    1089             if timeout >= 0 and ( time.time()-tic ) > timeout:
#    1090                 break
# -> 1091             time.sleep(1e-3)
#    1092             self.spin()
#    1093         return len(theids.intersection(self.outstanding)) == 0
#
# KeyboardInterrupt:

# %%
A = numpy.array(A)

# %%
d = c.direct_view(targets=[8,])

# %%
d.push({'fname': fnames[0]}, block=True)
fn = d.pull('fname', block=True)
r1 = d.execute('p = pop_model.POPFile(fname)', block=True)
r2 = d.execute('m = p.mask.shape')
m = d.pull('m')
m.get()
# Out:
# [(2400, 3600)]

# %%
len(c)
# Out:
# 1

# %%
dview.execute('import platform')
dview.execute('n = natl.rholevs.max()')
dview.pull('n').get()
# Out:
# [1028.5,
#  1028.5,
#  1028.5,
#  1028.5,
#  1028.5,
#  1028.5,
#  1028.5,
#  1028.5,
#  1028.5,
#  1028.5,
#  1028.5,
#  1028.5,
#  1028.5,
#  1028.5,
#  1028.5]

# %%
print p.nc.variables['SFWF_2']
# Out:
# <type 'netCDF4.Variable'>
# float32 SFWF_2(time, nlat, nlon)
#     long_name: Virtual Salt Flux in FW Flux formulation
#     units: kg/m^2/s
#     coordinates: TLONG TLAT time
#     grid_loc: 2110
#     cell_methods: time: mean
#     _FillValue: 9.96921e+36
#     missing_value: 9.96921e+36
# unlimited dimensions: time
# current shape = (31, 2400, 3600)

# %%
leg = ['Thermal','Haline','Tmix','Smix','Total']
plt.figure(figsize=(10,4))
plt.plot(natl.rholevs[1:] - 1000,  numpy.array([1.,10.,1.,1.])[numpy.newaxis,:]*A.mean(axis=0).T / 1e6, '.-')
plt.plot(natl.rholevs[1:] - 1000, (numpy.array([1.,10.,1.,1.])[:,numpy.newaxis]*A.mean(axis=0)).sum(axis=0) / 1e6, 'k.-')
plt.legend(leg, loc='lower left')
plt.grid()

# %%
T = numpy.arange(A.shape[0])

plt.figure(figsize=(16,12))
for n in range(4):
    plt.subplot(4,1,n+1)
    plt.pcolormesh(T, natl.rholevs[1:] - 1000,
                   A[:,n,:].T / 1e6, cmap='RdBu_r')
    plt.clim((-100,100))
    plt.title(leg[n])

# %%
numpy.savez('../data/A_natl.npz', A=A, rholevs=natl.rholevs, T=T)
