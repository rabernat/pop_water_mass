# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
expt = 'WMT_rho_hconst050_new'
regions = ['natl', 'npac', 'so']
d = dict()

for r in regions:
    d[r] = np.load('../data/%s_%s.npz' % (expt, r))
T = np.arange(d['natl']['A'].shape[0])/12.

# create seasonal and annual means
A_seasonal = dict()
A_annmean = dict()
month = np.mod(T*12,12)+1
seasons = dict(
    djf = (month==12) | (month==1) | (month==2),
    mam = (month==3) | (month==4) | (month==5),
    jja = (month==6) | (month==7) | (month==8),
    son = (month==9) | (month==10) | (month==11) )
for r in regions:
    A_annmean[r] = d[r]['A'].mean(axis=0)
    A_seasonal[r] = dict()
    for s, sidx in seasons.iteritems():
        A_seasonal[r][s] = d[r]['A'][sidx].mean(axis=0)

# %%
r = 'so'
Sv = 1e6

f = plt.figure(figsize=(12,3.5))

plt.subplot(131)
plt.plot(d[r]['rholevs'][1:] - 1000., -A_seasonal[r]['djf'].sum(axis=0)/ Sv, 'k-', linewidth=2)
plt.plot(d[r]['rholevs'][1:] - 1000., -A_seasonal[r]['djf'].T/ Sv)
plt.grid()
plt.legend(['Net','HF','FWF','Mixing', 'Cabbeling'], loc='lower left')
plt.title('DJF')

plt.subplot(132)
plt.plot(d[r]['rholevs'][1:] - 1000., -A_annmean[r].sum(axis=0)/ Sv, 'k-', linewidth=2)
plt.plot(d[r]['rholevs'][1:] - 1000., -A_annmean[r].T/ Sv)
plt.grid()
plt.title('Annual Mean')

plt.subplot(133)
plt.plot(d[r]['rholevs'][1:] - 1000., -A_seasonal[r]['jja'].sum(axis=0)/ Sv, 'k-', linewidth=2)
plt.plot(d[r]['rholevs'][1:] - 1000., -A_seasonal[r]['jja'].T/ Sv)
plt.grid()
plt.title('JJA')

# %%
plt.figure(figsize=(18,6))
plt.pcolormesh(T, d['so']['rholevs'][1:], np.cumsum(d['so']['A'][:,2,:], axis=1).T)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10f222b48>

# %%
r = 'so'
plt.plot(d[r]['rholevs'][1:] - 1000., np.cumsum(A_annmean[r][2]))
for s in ['jja','djf']:
    plt.plot(d[r]['rholevs'][1:] - 1000., np.cumsum(A_seasonal[r][s][2]))

# %%
d[r]['rholevs']
# Out:
# array([ 1028.5       ,  1028.44537815,  1028.3907563 ,  1028.33613445,
#         1028.28151261,  1028.22689076,  1028.17226891,  1028.11764706,
#         1028.06302521,  1028.00840336,  1027.95378151,  1027.89915966,
#         1027.84453782,  1027.78991597,  1027.73529412,  1027.68067227,
#         1027.62605042,  1027.57142857,  1027.51680672,  1027.46218487,
#         1027.40756303,  1027.35294118,  1027.29831933,  1027.24369748,
#         1027.18907563,  1027.13445378,  1027.07983193,  1027.02521008,
#         1026.97058824,  1026.91596639,  1026.86134454,  1026.80672269,
#         1026.75210084,  1026.69747899,  1026.64285714,  1026.58823529,
#         1026.53361345,  1026.4789916 ,  1026.42436975,  1026.3697479 ,
#         1026.31512605,  1026.2605042 ,  1026.20588235,  1026.1512605 ,
#         1026.09663866,  1026.04201681,  1025.98739496,  1025.93277311,
#         1025.87815126,  1025.82352941,  1025.76890756,  1025.71428571,
#         1025.65966387,  1025.60504202,  1025.55042017,  1025.49579832,
#         1025.44117647,  1025.38655462,  1025.33193277,  1025.27731092,
#         1025.22268908,  1025.16806723,  1025.11344538,  1025.05882353,
#         1025.00420168,  1024.94957983,  1024.89495798,  1024.84033613,
#         1024.78571429,  1024.73109244,  1024.67647059,  1024.62184874,
#         1024.56722689,  1024.51260504,  1024.45798319,  1024.40336134,
#         1024.3487395 ,  1024.29411765,  1024.2394958 ,  1024.18487395,
#         1024.1302521 ,  1024.07563025,  1024.0210084 ,  1023.96638655,
#         1023.91176471,  1023.85714286,  1023.80252101,  1023.74789916,
#         1023.69327731,  1023.63865546,  1023.58403361,  1023.52941176,
#         1023.47478992,  1023.42016807,  1023.36554622,  1023.31092437,
#         1023.25630252,  1023.20168067,  1023.14705882,  1023.09243697,
#         1023.03781513,  1022.98319328,  1022.92857143,  1022.87394958,
#         1022.81932773,  1022.76470588,  1022.71008403,  1022.65546218,
#         1022.60084034,  1022.54621849,  1022.49159664,  1022.43697479,
#         1022.38235294,  1022.32773109,  1022.27310924,  1022.21848739,
#         1022.16386555,  1022.1092437 ,  1022.05462185,  1022.        ])

# %%
expt = 'hconst050'
regions = ['natl', 'npac', 'so', 'globe']
dts = dict()

for r in regions:
    dts[r] = np.load('../data/A_TS_%s_%s.npz' % (expt, r))
T = np.arange(dts['natl']['A'].shape[0])/12.

# %%
from watermasstools import transformation
NT = 70
NS = 72
Tlevs = np.linspace(-2,34,NT)
Slevs = np.linspace(28,41,NS)
globe = transformation.TSWaterMassRegion(Tlevs=Tlevs, Slevs=Slevs)

# %%
plt.pcolormesh(globe.S, globe.T, dts['globe']['A'].mean(axis=0)[0,1]/Sv, cmap='RdBu_r')
plt.clim([-20,20])

# %%
plt.subplot(211)
plt.plot(globe.Tc, (dts['globe']['A'].mean(axis=0)[0,0] * globe.DT[np.newaxis,:,np.newaxis]).sum(axis=2).T)
plt.plot(globe.Tc, (dts['globe']['A'].mean(axis=0)[0,1] * globe.DT[np.newaxis,:,np.newaxis]).sum(axis=2).T)
plt.subplot(212)
plt.plot(globe.Sc, (dts['globe']['A'].mean(axis=0)[1,0] * globe.DS[np.newaxis,np.newaxis,:]).sum(axis=1).T)
plt.plot(globe.Sc, (dts['globe']['A'].mean(axis=0)[1,1] * globe.DS[np.newaxis,np.newaxis,:]).sum(axis=1).T)
